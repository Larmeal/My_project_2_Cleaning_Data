# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_1 = pd.read_excel("C:/Users/acer/Desktop/xrd.xlsx", usecols=["y_axis", "x_axis"])
data_1
# Out:
#          y_axis  x_axis
# 0     10.001506    40.0
# 1     10.021790    39.0
# 2     10.042073    35.0
# 3     10.062357    35.0
# 4     10.082640    33.0
# ...         ...     ...
# 3447        NaN     NaN
# 3448        NaN     NaN
# 3449        NaN     NaN
# 3450        NaN     NaN
# 3451        NaN     NaN
#
# [3452 rows x 2 columns]

# %%
data_1.isnull()
# Out:
#       y_axis  x_axis
# 0      False   False
# 1      False   False
# 2      False   False
# 3      False   False
# 4      False   False
# ...      ...     ...
# 3447    True    True
# 3448    True    True
# 3449    True    True
# 3450    True    True
# 3451    True    True
#
# [3452 rows x 2 columns]

# %%
data_1.dropna(subset=["y_axis", "x_axis"], inplace=True)

# %%
data_1
# Out:
#          y_axis  x_axis
# 0     10.001506    40.0
# 1     10.021790    39.0
# 2     10.042073    35.0
# 3     10.062357    35.0
# 4     10.082640    33.0
# ...         ...     ...
# 2461  59.918914    36.0
# 2462  59.939197    19.0
# 2463  59.959481    36.0
# 2464  59.979764    42.0
# 2465  60.000047    39.0
#
# [2466 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
plt.plot(data_1["y_axis"], data_1["x_axis"])
plt.title("Vanadyl Phosphate Dihydrate, $VO(PO_4)(H_2O)_2$", size=16, pad=10)
plt.ylabel("Intensity (cps)", size=16)
plt.xlabel("2-theta (◦)", size=14)
plt.ylim(0, 1000)
plt.xlim(10, 45)
plt.text(x=13, y=800, s="12.0907")
plt.text(x=15.5, y=140, s="18.8045")
plt.text(x=25, y=700, s="24.0985")
plt.text(x=26, y=230, s="28.1754")
plt.text(x=27.8, y=450, s="28.9665")
plt.text(x=30.1, y=210, s="31.4005")
plt.text(x=34.5, y=150, s="37.8912")
plt.text(x=37.6, y=480, s="39.1893")
plt.text(x=40.5, y=100, s="41.2988")
plt.show()
